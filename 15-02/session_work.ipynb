# %%
 import pandas as pd

# %%
data = pd.read_csv("50_Startups.csv")

# %%
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit
# 0  165349.20       136897.80        471784.10  192261.83
# 1  162597.70       151377.59        443898.53  191792.06
# 2  153441.51       101145.55        407934.54  191050.39
# 3  144372.41       118671.85        383199.62  182901.99
# 4  142107.34        91391.77        366168.42  166187.94

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        46 non-null     float64
#  1   Administration   46 non-null     float64
#  2   Marketing Spend  46 non-null     float64
#  3   Profit           46 non-null     float64
# dtypes: float64(4)
# memory usage: 1.6 KB

# %%
data.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# Profit             0
# dtype: int64

# %%
data.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      46.000000       46.000000        46.000000      46.000000
# mean    78241.718043   121947.043478    228393.083261  117063.925217
# std     43695.348335    26812.767940    111336.691801   35960.003971
# min      1000.230000    51283.140000      1903.930000   49490.750000
# 25%     46117.032500   103730.875000    142431.385000   96537.832500
# 50%     74661.715000   122699.795000    239452.750000  108643.015000
# 75%    111370.977500   144842.180000    302423.767500  143590.930000
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
import seaborn as sns
sns.pairplot(data)

# %%
import matplotlib.pyplot as plt
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
! pip install scikit-learn

# %%
x = data.drop('Profit', axis=1)
x
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0   165349.20       136897.80        471784.10
# 1   162597.70       151377.59        443898.53
# 2   153441.51       101145.55        407934.54
# 3   144372.41       118671.85        383199.62
# 4   142107.34        91391.77        366168.42
# 5   131876.90        99814.71        362861.36
# 6   134615.46       147198.87        127716.82
# 7   130298.13       145530.06        323876.68
# 8   120542.52       148718.95        311613.29
# 9   123334.88       108679.17        304981.62
# 10  101913.08       110594.11        229160.95
# 11  100671.96        91790.61        249744.55
# 12   93863.75       127320.38        249839.44
# 13   91992.39       135495.07        252664.93
# 14  119943.24       156547.42        256512.92
# 15  114523.61       122616.84        261776.23
# 16   78013.11       121597.55        264346.06
# 17   94657.16       145077.58        282574.31
# 18   91749.16       114175.79        294919.57
# ...

# %%
y = data['Profit']
y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    118474.03
# 20    111313.02
# 21    110352.25
# 22    108733.99
# 23    108552.04
# 24    107404.34
# 25    105733.54
# 26    105008.31
# 27    103282.38
# 28    101004.64
# 29     99937.59
# 30     97483.56
# 31     97427.84
# 32     96778.92
# 33     96712.80
# 34     96479.51
# 35     90708.19
# 36     89949.14
# 37     81229.06
# 38     81005.76
# 39     78239.91
# 40     77798.83
# 41     71498.49
# 42     69758.98
# 43     65200.33
# 44     64926.08
# 45     49490.75
# Name: Profit, dtype: float64

# %%
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state= 42, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print("Training Accurecy", model.score(x_train, y_train))
print("Testing  Accurecy", model.score(x_test, y_test))
# Out:
# Training Accurecy 0.9650159552087179
# Testing  Accurecy 0.946536125477149

# %%
y_pred = model.predict(x_test)

# %%
plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # ideal line
plt.xlabel('Actual Profit')
plt.ylabel('Predicted Profit')
plt.title('Actual vs Predicted')
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted')

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print("R² Score:", r2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 2
#       1 from sklearn.metrics import r2_score
# ----> 2 r2 = r2_score(y_test, y_pred)
#       3 print("R² Score:", r2)
#
# File ~/anaconda3/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
# ...

# %% [markdown]
# # SGDRegressor

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

sgd = SGDRegressor(learning_rate='adaptive', eta0=0.5)
sgd.fit(X_train_scaled, y_train)
# Out:
# SGDRegressor(eta0=0.5, learning_rate='adaptive')

# %%
y_pred_2 = sgd.predict(X_test_scaled)

# %%
from sklearn.metrics import r2_score, mean_squared_error
print("R² Score:", r2_score(y_test, y_pred_2))
print("MSE:", mean_squared_error(y_test, y_pred_2))
# Out:
# R² Score: 0.9464622637272139
# MSE: 84810007.39572601
